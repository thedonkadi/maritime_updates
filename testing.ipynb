# %%
import easyocr
reader = easyocr.Reader(['en'], gpu=False)
# Out:
# Using CPU. Note: This module is much faster with a GPU.

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt

# Initialize the EasyOCR reader
reader = easyocr.Reader(['en'])  # You can specify languages like ['en', 'fr', 'de']

# Load an image using OpenCV
image_path = 'handwritten_image_1.jpeg'
img = cv2.imread(image_path)

if img is None:
    print("Error: Could not load image.")
else:
    # Use EasyOCR to read text from the image
    result = reader.readtext(img)

    # Display results
    for (bbox, text, prob) in result:
        print(f"Detected text: {text} (Confidence: {prob:.2f})")
        
        # Draw bounding box around detected text
        (top_left, top_right, bottom_right, bottom_left) = bbox
        top_left = tuple(map(int, top_left))
        bottom_right = tuple(map(int, bottom_right))
        cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 2)

    # Show the image with detected text
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: Dte (Confidence: 1.00)
# Detected text: J0ny -(o (Confidence: 0.11)
# Detected text: Qo (Confidence: 0.53)
# Detected text: Time (Confidence: 0.85)
# Detected text: [L: 30 (Confidence: 0.35)
# Detected text: o€c (Confidence: 0.11)
# Detected text: Qa-trel (Confidence: 0.40)
# Detected text: Alpha (Confidence: 0.84)
# Detected text: Locati on^ (Confidence: 0.32)
# Detected text: Uesgel (Confidence: 0.34)
# Detected text: cbseruel | (Confidence: 0.53)
# Detected text: at (Confidence: 1.00)
# Detected text: I3816'N (Confidence: 0.58)
# Detected text: #"z0w (Confidence: 0.41)
# Detected text: Raqort (Confidence: 0.17)
# Detected text: (ago (Confidence: 0.55)
# Detected text: 12 (Confidence: 1.00)
# Detected text: knots (Confidence: 0.99)
# Detected text: No Suspatitus aulivi-ty (Confidence: 0.24)
# Detected text: Hleac (Confidence: 0.33)
# ...

# %%
import easyocr
import cv2

def extract_and_print_text(image_path):
    # Initialize the EasyOCR reader
    reader = easyocr.Reader(['en'])  # Specify languages as needed

    # Load the image
    img = cv2.imread(image_path)
    if img is None:
        print("Error: Could not load image.")
        return

    # Use EasyOCR to read text from the image
    result = reader.readtext(img)

    # Extract and concatenate all detected text
    full_text = " ".join([text for (_, text, _) in result])

    # Print the entire detected text
    print("Detected Text:\n", full_text)

# Example usage
image_path = 'uploads\Screenshot 1.png'
extract_and_print_text(image_path)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected Text:
#  Date: 2024-10-20 Time 14:30 UTC Location Patrol Vessel Alpha Report: Cargo vessel observed at 13015 'N, 71 30 ' W Heading 045 speed 12 knots No suspicious activity.

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

import pytesseract
# Out:
# 'sudo' is not recognized as an internal or external command,
# operable program or batch file.
# ...
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from PIL import Image

# Load image
image_path = "uploads\Screenshot 1.png"
image = Image.open(image_path)

# %%
# !pip install paddlepaddle paddleocr
# Out:
# ...
# WARNING: Ignoring invalid distribution -treamlit (c:\users\syam\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\syam\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -treamlit (c:\users\syam\appdata\local\programs\python\python310\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-health-checking 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.2 which is incompatible.
# grpcio-status 1.62.3 requires protobuf>=4.21.6, but you have protobuf 3.20.2 which is incompatible.
# grpcio-tools 1.62.3 requires protobuf<5.0dev,>=4.21.6, but you have protobuf 3.20.2 which is incompatible.
# langchain-google-calendar-tools 0.0.1 requires protobuf>=4.25.0, but you have protobuf 3.20.2 which is incompatible.
# ...

# %%
# Define the path to the image
image_path = 'uploads\Screenshot 1.png' # Replace with your image file path

# Load image and prepare request
from paddleocr import PaddleOCR

# Initialize OCR
ocr = PaddleOCR(use_angle_cls=True, lang='en')

# Perform OCR
result = ocr.ocr(image_path, cls=True)
extracted_text = "\n".join([line[1][0] for line in result[0]])
print("Extracted Text:", extracted_text)
# Out:
# [2024/10/25 23:24:39] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=False, use_xpu=False, use_npu=False, use_mlu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir=None, page_num=0, det_algorithm='DB', det_model_dir='C:\\Users\\SYAM/.paddleocr/whl\\det\\en\\en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='C:\\Users\\SYAM/.paddleocr/whl\\rec\\en\\en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=
# ...

# %%
image_path = 'uploads\Screenshot 1.png'
# Perform OCR
result = ocr.ocr(image_path, cls=True)
extracted_text = "\n".join([line[1][0] for line in result[0]])
print("Extracted Text:", extracted_text)
# Out:
# [2024/10/25 23:26:19] ppocr DEBUG: dt_boxes num : 4, elapsed : 0.6215133666992188
# [2024/10/25 23:26:19] ppocr DEBUG: cls num  : 4, elapsed : 0.16171693801879883
# [2024/10/25 23:26:22] ppocr DEBUG: rec_res num  : 4, elapsed : 2.755890369415283
# Extracted Text: Date: 2024-10-20
# Time: 14:30 UTC
# Location: Patrol Vessel Alpha
# Report: Cargo vessel observed at 13'15'N, 7130'w. Heading 045', speed 12 knots. No suspicious activity.

# %%
import pytesseract
from PIL import Image

# Check for Tesseract installation
try:
    pytesseract.get_tesseract_version()
except EnvironmentError:
    print("Tesseract OCR is not installed.")
    raise
# Out:
# Tesseract OCR is not installed.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File e:\langflow_directory\maritime_venv\lib\site-packages\pytesseract\pytesseract.py:451, in get_tesseract_version()
#     450 try:
# --> 451     output = subprocess.check_output(
#     452         [tesseract_cmd, '--version'],
#     453         stderr=subprocess.STDOUT,
#     454         env=environ,
#     455         stdin=subprocess.DEVNULL,
#     456     )
#     457 except OSError:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:421, in check_output(timeout, *popenargs, **kwargs)
#     419     kwargs['input'] = empty
# --> 421 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
# ...

# %%
# Set path to tessdata if needed
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# OCR function
def ocr_image(image_path):
    image = Image.open(image_path)
    return pytesseract.image_to_string(image)

print(ocr_image('uploads\Screenshot_1.png'))
# Out:
# Date: 2024-10-20
# Time: 14:30 UTC
#
# Location: Patrol Vessel Alpha
#
# Report: Cargo vessel observed at 13°15'N, 71°30'W. Heading 045°, speed 12 knots. No suspicious activity.
